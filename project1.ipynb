# %%
pip install faker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install faker
# Out:
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------- ----------------- 1.0/1.9 MB 6.6 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 4.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip intall pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "intall" - maybe you meant "install"

# %%
import pandas as pd
from faker import Faker
import random
from datetime import datetime

# Initialize Faker instance
fake = Faker()

# Define some expense categories
categories = ['Food', 'Transport', 'Entertainment', 'Utilities', 'Shopping', 'Healthcare', 'Rent', 'Bills', 'investment','fees','Sports and Fitness','Subscription','travel','Gifts']

# Create a list to store expense data
expense_data = []

# Generate 100-150 entries
num_entries = random.randint(0, 141)

for _ in range(num_entries):
    expense = {
        'Date': fake.date_this_month().strftime('%Y-%m-%d'),  # Random date within this month
        'Category': random.choice(categories),  # Randomly pick a category
        'Amount': round(random.uniform(5.0, 500.0), 2),  # Random amount between 5 and 500, rounded to 2 decimals
        'Description': fake.sentence(nb_words=5),  # Random description (short sentence)
    }
    expense_data.append(expense)

# Create a pandas DataFrame from the list of expenses
df = pd.DataFrame(expense_data)

# Optionally, save the data to a CSV file
df.to_csv('january_expenses.csv', index=False)

# Display the first few rows of the table
print(df.head())

# %%
import pandas as pd
from faker import Faker
import random
from datetime import datetime

# Initialize Faker instance
fake = Faker()

# Define some realistic descriptions for each category
expense_descriptions = {
    'Food': [
        'Lunch at restaurant', 'Dinner delivery', 'Grocery shopping', 
        'Coffee at café', 'Bought snacks', 'Fast food meal', 'Weekly groceries'
    ],
    'Transport': [
        'Uber ride', 'Taxi fare', 'Gas station refill', 'Public transport ticket',
        'Parking fee', 'Train fare', 'Car repair'
    ],
    'Entertainment': [
        'Movie ticket', 'Concert ticket', 'Theatre show', 'Streaming subscription', 
        'Books purchase', 'Video games', 'Dinner and drinks'
    ],
    'Utilities': [
        'Electricity bill', 'Water bill', 'Internet subscription', 
        'Mobile phone bill', 'Gas bill', 'Cable TV subscription'
    ],
    'Shopping': [
        'Clothing purchase', 'New shoes', 'Bought electronics', 'Shopping for accessories', 
        'Online shopping', 'Gift purchase', 'Home decor'
    ],
    'Healthcare': [
        'Doctor visit', 'Medicine purchase', 'Dental check-up', 'Eye exam', 
        'Prescription glasses', 'Gym membership', 'Health insurance'
    ],
    'Rent': [
        'Monthly rent', 'House rent payment', 'Apartment rent', 'Room rent payment'
    ],
    'Investments': [
        'stocks','LIC','SIP','mutual funds'
    ],
    'Stationary': [
        'Pens','Charts','Sheets','Sketch Pens','declutter boxes'
    ],
    'Travel':[
        'Sunday picnics','Hastinapur tour','South Tour','Mall visit','Movies'

    ]
}

# Define payment modes
payment_modes = ['Cash', 'Credit Card', 'Debit Card', 'Bank Transfer', 'Mobile Payment']

# Create a list to store expense data
expense_data = []

# Generate 140 entries
num_entries = random.randint(0, 140)

for _ in range(num_entries):
    # Randomly select category
    category = random.choice(list(expense_descriptions.keys()))
    
    # Randomly select a description from the category
    description = random.choice(expense_descriptions[category])
    
    # Randomly generate the expense amount
    amount = round(random.uniform(5.0, 500.0), 2)
    
    # Generate a random payment mode
    payment_mode = random.choice(payment_modes)
    
    # Generate random date within this month
    date = fake.date_this_month().strftime('%Y-%m-%d')
    
    # Append data to the expense list
    expense_data.append({
        'Date': date,
        'Category': category,
        'Amount': amount,
        'Description': description,
        'Payment Mode': payment_mode
    })

# Create a pandas DataFrame from the list of expenses
df = pd.DataFrame(expense_data)

# Optionally, save the data to a CSV file
df.to_csv('january_expenses_with_payment_mode.csv', index=False)

# Display the first few rows of the table
print(df.head())
# Out:
#          Date    Category  Amount         Description    Payment Mode
# 0  2025-01-10        Food  304.94      Fast food meal  Mobile Payment
# 1  2025-01-21      Travel   68.76          South Tour      Debit Card
# 2  2025-01-15      Travel  354.42          Mall visit  Mobile Payment
# 3  2025-01-08  Healthcare   62.27   Medicine purchase   Bank Transfer
# 4  2025-01-15        Rent  287.29  House rent payment   Bank Transfer

# %%
import pandas as pd
from faker import Faker
import random
from datetime import datetime

# Initialize Faker instance
fake = Faker()

# Define some realistic descriptions for each category
expense_descriptions = {
    'Food': [
        'Lunch at restaurant', 'Dinner delivery', 'Grocery shopping', 
        'Coffee at café', 'Bought snacks', 'Fast food meal', 'Weekly groceries'
    ],
    'Transport': [
        'Uber ride', 'Taxi fare', 'Gas station refill', 'Public transport ticket',
        'Parking fee', 'Train fare', 'Car repair'
    ],
    'Entertainment': [
        'Movie ticket', 'Concert ticket', 'Theatre show', 'Streaming subscription', 
        'Books purchase', 'Video games', 'Dinner and drinks'
    ],
    'Utilities': [
        'Electricity bill', 'Water bill', 'Internet subscription', 
        'Mobile phone bill', 'Gas bill', 'Cable TV subscription'
    ],
    'Shopping': [
        'Clothing purchase', 'New shoes', 'Bought electronics', 'Shopping for accessories', 
        'Online shopping', 'Gift purchase', 'Home decor'
    ],
    'Healthcare': [
        'Doctor visit', 'Medicine purchase', 'Dental check-up', 'Eye exam', 
        'Prescription glasses', 'Gym membership', 'Health insurance'
    ],
    'Rent': [
        'Monthly rent', 'House rent payment', 'Apartment rent', 'Room rent payment'
    ],
    'Investments': [
        'stocks','LIC','SIP','mutual funds'
    ],
    'Stationary': [
        'Pens','Charts','Sheets','Sketch Pens','declutter boxes'
    ],
    'Travel':[
        'Sunday picnic','Hastinapur tour','South Tour','Mall visit','Movies'

    ]
}

# Define payment modes
payment_modes = ['Cash', 'Credit Card', 'Debit Card', 'Bank Transfer', 'Mobile Payment']

# Create a list to store expense data
expense_data = []

# Generate 140 entries
num_entries = 140

# Cashback percentage range (for Credit Card or Debit Card)
cashback_percentage_range = (1, 5)  # Cashback between 1% to 5%

for _ in range(num_entries):
    # Randomly select category
    category = random.choice(list(expense_descriptions.keys()))
    
    # Randomly select a description from the category
    description = random.choice(expense_descriptions[category])
    
    # Randomly generate the expense amount
    amount = round(random.uniform(5.0, 500.0), 2)
    
    # Generate a random payment mode
    payment_mode = random.choice(payment_modes)

    # Calculate cashback only for Credit Card or Debit Card payment modes
    cashback = 0
    if payment_mode in ['Credit Card', 'Debit Card']:
        cashback_percentage = random.uniform(*cashback_percentage_range)  # Random cashback percentage
        cashback = round(amount * cashback_percentage / 100, 2)  # Calculate cashback
    
    # Generate random date within this month
    date = fake.date_this_month().strftime('%Y-%m-%d')
    
    # Append data to the expense list
    expense_data.append({
        'Date': date,
        'Category': category,
        'Amount': amount,
        'Description': description,
        'Payment Mode': payment_mode,
        'Cashback': cashback
    })

# Create a pandas DataFrame from the list of expenses
df = pd.DataFrame(expense_data)

# Optionally, save the data to a CSV file
df.to_csv('january_expenses.csv', index=False)

# Display the first few rows of the table
print(df.head())
# Out:
#          Date     Category  Amount              Description   Payment Mode  \
# 0  2025-01-21    Transport  458.56  Public transport ticket     Debit Card
# 1  2025-01-17  Investments  295.81                   stocks  Bank Transfer
# 2  2025-01-17   Healthcare  422.57     Prescription glasses           Cash
# 3  2025-01-17     Shopping  378.60       Bought electronics    Credit Card
# 4  2025-01-01         Food   13.12      Lunch at restaurant           Cash
#
#    Cashback
# 0     16.00
# 1      0.00
# 2      0.00
# 3     13.99
# 4      0.00

# %%
import pandas as pd
from faker import Faker
import random
from datetime import datetime

# Function to get a random date in november for the current year
def get_random_november_dates_current_year():
    # Get the current year
    current_year = datetime.today().year
    
    # december has 30 days
    days_in_november = 30
    
    # Generate a random day in november (between 1 and 30 )
    random_day = random.randint(1, days_in_november)
    
    # Return the random date in december for the current year
    random_date = datetime(current_year, 11, random_day).strftime('%Y-%m-%d')
    
    return random_date



# Initialize Faker instance
fake = Faker()

# Define some realistic descriptions for each category
expense_descriptions = {
    'Food': [
        'Lunch at restaurant', 'Dinner delivery', 'Grocery shopping', 
        'Coffee at café', 'Bought snacks', 'Fast food meal', 'Weekly groceries'
    ],
    'Transport': [
        'Uber ride', 'Taxi fare', 'Gas station refill', 'Public transport ticket',
        'Parking fee', 'Train fare', 'Car repair'
    ],
    'Entertainment': [
        'Movie ticket', 'Concert ticket', 'Theatre show', 'Streaming subscription', 
        'Books purchase', 'Video games', 'Dinner and drinks'
    ],
    'Utilities': [
        'Electricity bill', 'Water bill', 'Internet subscription', 
        'Mobile phone bill', 'Gas bill', 'Cable TV subscription'
    ],
    'Shopping': [
        'Clothing purchase', 'New shoes', 'Bought electronics', 'Shopping for accessories', 
        'Online shopping', 'Gift purchase', 'Home decor'
    ],
    'Healthcare': [
        'Doctor visit', 'Medicine purchase', 'Dental check-up', 'Eye exam', 
        'Prescription glasses', 'Gym membership', 'Health insurance'
    ],
    'Rent': [
        'Monthly rent', 'House rent payment', 'Apartment rent', 'Room rent payment'
    ],
    'Investments': [
        'stocks','LIC','SIP','mutual funds'
    ],
    'Stationary': [
        'Pens','Charts','Sheets','Sketch Pens','declutter boxes'
    ],
    'Travel':[
        'Sunday picnic','Hastinapur tour','South Tour','Mall visit','Movies'

    ]
}

# Define payment modes
payment_modes = ['Cash', 'Credit Card', 'Debit Card', 'Bank Transfer', 'Mobile Payment']

# Create a list to store expense data
expense_data = []

# Generate 142 entries
num_entries = 147

# Cashback percentage range (for Credit Card or Debit Card)
cashback_percentage_range = (1, 4)  # Cashback between 1% to 10%

for _ in range(num_entries):
    # Randomly select category
    category = random.choice(list(expense_descriptions.keys()))
    
    # Randomly select a description from the category
    description = random.choice(expense_descriptions[category])
    
    # Randomly generate the expense amount
    amount = round(random.uniform(5.0, 500.0), 2)
    
    # Generate a random payment mode
    payment_mode = random.choice(payment_modes)

    # Calculate cashback only for Credit Card or Debit Card payment modes
    cashback = 0
    if payment_mode in ['Credit Card', 'Debit Card']:
        cashback_percentage = random.uniform(*cashback_percentage_range)  # Random cashback percentage
        cashback = round(amount * cashback_percentage / 100, 2)  # Calculate cashback
    
    # Generate a random date for november (this year)
    date = get_random_november_dates_current_year()
    
    # Append data to the expense list
    expense_data.append({
        'Date': date,
        'Category': category,
        'Amount': amount,
        'Description': description,
        'Payment Mode': payment_mode,
        'Cashback': cashback
    })

# Create a pandas DataFrame from the list of expenses
df = pd.DataFrame(expense_data)

# Optionally, save the data to a CSV file
df.to_csv('November_expenses1.csv', index=False)

# Display the first few rows of the table
print(df.head())
# Out:
#          Date       Category  Amount        Description   Payment Mode  \
# 0  2025-11-08         Travel   41.78             Movies     Debit Card
# 1  2025-11-25  Entertainment  247.93       Theatre show  Bank Transfer
# 2  2025-11-14           Food   89.92     Coffee at café    Credit Card
# 3  2025-11-11         Travel  380.96         Mall visit           Cash
# 4  2025-11-24      Utilities  142.22  Mobile phone bill     Debit Card
#
#    Cashback
# 0      1.31
# 1      0.00
# 2      2.15
# 3      0.00
# 4      1.48

# %%
import pandas as pd
from faker import Faker
import random
from datetime import datetime

# Function to get a random date in September for the current year
def get_random_september_dates_current_year():
    # Get the current year
    current_year = datetime.today().year
    
    # September has 30 days
    days_in_september = 30
    
    # Generate a random day in September (between 1 and 30)
    random_day = random.randint(1, days_in_september)
    
    # Return the random date in September for the current year
    random_date = datetime(current_year, 9, random_day).strftime('%Y-%m-%d')
    
    return random_date



# Initialize Faker instance
fake = Faker()

# Define some realistic descriptions for each category
expense_descriptions = {
    'Food': [
        'Lunch at restaurant', 'Dinner delivery', 'Grocery shopping', 
        'Coffee at café', 'Bought snacks', 'Fast food meal', 'Weekly groceries'
    ],
    'Transport': [
        'Uber ride', 'Taxi fare', 'Gas station refill', 'Public transport ticket',
        'Parking fee', 'Train fare', 'Car repair'
    ],
    'Entertainment': [
        'Movie ticket', 'Concert ticket', 'Theatre show', 'Streaming subscription', 
        'Books purchase', 'Video games', 'Dinner and drinks'
    ],
    'Utilities': [
        'Electricity bill', 'Water bill', 'Internet subscription', 
        'Mobile phone bill', 'Gas bill', 'Cable TV subscription'
    ],
    'Shopping': [
        'Clothing purchase', 'New shoes', 'Bought electronics', 'Shopping for accessories', 
        'Online shopping', 'Gift purchase', 'Home decor'
    ],
    'Healthcare': [
        'Doctor visit', 'Medicine purchase', 'Dental check-up', 'Eye exam', 
        'Prescription glasses', 'Gym membership', 'Health insurance'
    ],
    'Rent': [
        'Monthly rent', 'House rent payment', 'Apartment rent', 'Room rent payment'
    ],
    'Investments': [
        'stocks','LIC','SIP','mutual funds'
    ],
    'Stationary': [
        'Pens','Charts','Sheets','Sketch Pens','declutter boxes'
    ],
    'Travel':[
        'Sunday picnic','Hastinapur tour','South Tour','Mall visit','Movies'

    ]
}

# Define payment modes
payment_modes = ['Cash', 'Credit Card', 'Debit Card', 'Bank Transfer', 'Mobile Payment']

# Create a list to store expense data
expense_data = []

# Generate 147 entries
num_entries = 147

# Cashback percentage range (for Credit Card or Debit Card)
cashback_percentage_range = (1, 9)  # Cashback between 1% to 9%

for _ in range(num_entries):
    # Randomly select category
    category = random.choice(list(expense_descriptions.keys()))
    
    # Randomly select a description from the category
    description = random.choice(expense_descriptions[category])
    
    # Randomly generate the expense amount
    amount = round(random.uniform(5.0, 500.0), 2)
    
    # Generate a random payment mode
    payment_mode = random.choice(payment_modes)

    # Calculate cashback only for Credit Card or Debit Card payment modes
    cashback = 0
    if payment_mode in ['Credit Card', 'Debit Card']:
        cashback_percentage = random.uniform(*cashback_percentage_range)  # Random cashback percentage
        cashback = round(amount * cashback_percentage / 100, 2)  # Calculate cashback
    
    # Generate a random date for September (this year)
    date = get_random_september_dates_current_year()
    
    # Append data to the expense list
    expense_data.append({
        'Date': date,
        'Category': category,
        'Amount': amount,
        'Description': description,
        'Payment Mode': payment_mode,
        'Cashback': cashback
    })

# Create a pandas DataFrame from the list of expenses
df = pd.DataFrame(expense_data)

# Optionally, save the data to a CSV file
df.to_csv('September_expenses.csv', index=False)

# Display the first few rows of the table
print(df.head())
# Out:
#          Date     Category  Amount        Description Payment Mode  Cashback
# 0  2025-09-29   Healthcare  234.31     Gym membership   Debit Card      9.27
# 1  2025-09-04    Utilities  112.34  Mobile phone bill   Debit Card      2.20
# 2  2025-09-27   Stationary  145.05        Sketch Pens         Cash      0.00
# 3  2025-09-18    Utilities  188.87   Electricity bill         Cash      0.00
# 4  2025-09-30  Investments  277.86       mutual funds  Credit Card     20.25

# %%
import pyodbc

# Set up the connection string
server = 'localhost'  # or your server name
username = 'Mansi'


# Create the connection
connection_string = f'DRIVER={{ODBC Driver 17 for SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password}'

# Connect to the database
connection = pyodbc.connect(connection_string)

# Create a cursor object to interact with the database
cursor = connection.cursor()

# Example of a SQL query
cursor.execute('SELECT * FROM your_table_name')

# Fetch results
rows = cursor.fetchall()

for row in rows:
    print(row)

# Close the connection
connection.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 9
#       5 username = 'Mansi'
#       8 # Create the connection
# ----> 9 connection_string = f'DRIVER={{ODBC Driver 17 for SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password}'
#      11 # Connect to the database
#      12 connection = pyodbc.connect(connection_string)
#
# NameError: name 'database' is not defined

# %%
SELECT name FROM sys.databases;
# Out:
#   Cell In[25], line 1
#     SELECT name FROM sys.databases;
#            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from faker import Faker
import random
from datetime import datetime

# Function to get a random date in June for the current year
def get_random_june_dates_current_year():
    # Get the current year
    current_year = datetime.today().year
    
    # June has 30 days
    days_in_june = 30
    
    # Generate a random day in June (between 1 and 30)
    random_day = random.randint(1, days_in_june)
    
    # Return the random date in June for the current year
    random_date = datetime(current_year, 6, random_day).strftime('%Y-%m-%d')
    
    return random_date

# Initialize Faker instance
fake = Faker()

# Define some realistic descriptions for each category
expense_descriptions = {
    'Food': [
        'Lunch at restaurant', 'Dinner delivery', 'Grocery shopping', 
        'Coffee at café', 'Bought snacks', 'Fast food meal', 'Weekly groceries'
    ],
    'Transport': [
        'Uber ride', 'Taxi fare', 'Gas station refill', 'Public transport ticket',
        'Parking fee', 'Train fare', 'Car repair'
    ],
    'Entertainment': [
        'Movie ticket', 'Concert ticket', 'Theatre show', 'Streaming subscription', 
        'Books purchase', 'Video games', 'Dinner and drinks'
    ],
    'Utilities': [
        'Electricity bill', 'Water bill', 'Internet subscription', 
        'Mobile phone bill', 'Gas bill', 'Cable TV subscription'
    ],
    'Shopping': [
        'Clothing purchase', 'New shoes', 'Bought electronics', 'Shopping for accessories', 
        'Online shopping', 'Gift purchase', 'Home decor'
    ],
    'Healthcare': [
        'Doctor visit', 'Medicine purchase', 'Dental check-up', 'Eye exam', 
        'Prescription glasses', 'Gym membership', 'Health insurance'
    ],
    'Rent': [
        'Monthly rent', 'House rent payment', 'Apartment rent', 'Room rent payment'
    ],
    'Investments': [
        'stocks','LIC','SIP','mutual funds'
    ],
    'Stationary': [
        'Pens','Charts','Sheets','Sketch Pens','declutter boxes'
    ],
    'Travel':[
        'Sunday picnic','Hastinapur tour','South Tour','Mall visit','Movies'

    ]
}

# Define payment modes
payment_modes = ['Cash', 'Credit Card', 'Debit Card', 'Bank Transfer', 'Mobile Payment']

# Create a list to store expense data
expense_data = []

# Generate 137 entries
num_entries = 137

# Cashback percentage range (for Credit Card or Debit Card)
cashback_percentage_range = (1, 8)  # Cashback between 1% to 5%

for _ in range(num_entries):
    # Randomly select category
    category = random.choice(list(expense_descriptions.keys()))
    
    # Randomly select a description from the category
    description = random.choice(expense_descriptions[category])
    
    # Randomly generate the expense amount
    amount = round(random.uniform(5.0, 500.0), 2)
    
    # Generate a random payment mode
    payment_mode = random.choice(payment_modes)

    # Calculate cashback only for Credit Card or Debit Card payment modes
    cashback = 0
    if payment_mode in ['Credit Card', 'Debit Card']:
        cashback_percentage = random.uniform(*cashback_percentage_range)  # Random cashback percentage
        cashback = round(amount * cashback_percentage / 100, 2)  # Calculate cashback
    
   # Generate a random date for June (this year)
    date = get_random_june_dates_current_year()
    
    
    # Append data to the expense list
    expense_data.append({
        'Date': date,
        'Category': category,
        'Amount': amount,
        'Description': description,
        'Payment Mode': payment_mode,
        'Cashback': cashback
    })

# Create a pandas DataFrame from the list of expenses
df = pd.DataFrame(expense_data)

# Optionally, save the data to a CSV file
df.to_csv('May_expenses.csv', index=False)

# Display the first few rows of the table
print(df.head())
# Out:
#          Date    Category  Amount            Description Payment Mode  \
# 0  2025-05-15   Utilities   16.98  Internet subscription         Cash
# 1  2025-05-28        Rent  114.85      Room rent payment  Credit Card
# 2  2025-05-08   Utilities  275.39             Water bill         Cash
# 3  2025-05-25  Stationary  216.32                 Sheets   Debit Card
# 4  2025-05-17        Food    5.75         Coffee at café         Cash
#
#    Cashback
# 0      0.00
# 1      6.08
# 2      0.00
# 3     14.19
# 4      0.00

# %%
import pandas as pd

# Path to your CSV file (provide the correct path where your CSV is stored)
csv_file = 'january_expenses.csv'  # Replace with your actual file path

# Read CSV into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the first few rows of the DataFrame to verify it
print(df)
# Out:
#            Date       Category  Amount              Description  \
# 0    2025-01-21      Transport  458.56  Public transport ticket
# 1    2025-01-17    Investments  295.81                   stocks
# 2    2025-01-17     Healthcare  422.57     Prescription glasses
# 3    2025-01-17       Shopping  378.60       Bought electronics
# 4    2025-01-01           Food   13.12      Lunch at restaurant
# ..          ...            ...     ...                      ...
# 135  2025-01-17      Transport  290.61  Public transport ticket
# 136  2025-01-19           Food  247.25         Grocery shopping
# 137  2025-01-04      Transport  167.03              Parking fee
# 138  2025-01-01      Transport  167.29                Taxi fare
# 139  2025-01-10  Entertainment  468.02        Dinner and drinks
#
#       Payment Mode  Cashback
# 0       Debit Card     16.00
# 1    Bank Transfer      0.00
# 2             Cash      0.00
# 3      Credit Card     13.99
# 4             Cash      0.00
# ...

# %%
import pandas as pd

# Path to your CSV file (provide the correct path where your CSV is stored)
csv_file = 'February_expenses.csv'  # Replace with your actual file path

# Read CSV into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the first few rows of the DataFrame to verify it
print(df)
# Out:
#            Date     Category  Amount              Description    Payment Mode  \
# 0    2025-06-03    Utilities  420.51    Cable TV subscription     Credit Card
# 1    2025-06-22         Rent   84.03        Room rent payment            Cash
# 2    2025-06-13       Travel   24.26            Sunday picnic  Mobile Payment
# 3    2025-06-07  Investments  394.56                      SIP     Credit Card
# 4    2025-06-14    Transport  395.77  Public transport ticket   Bank Transfer
# ..          ...          ...     ...                      ...             ...
# 132  2025-06-20    Transport  341.56  Public transport ticket   Bank Transfer
# 133  2025-06-12  Investments   99.25             mutual funds      Debit Card
# 134  2025-06-29  Investments  405.64                      LIC   Bank Transfer
# 135  2025-06-17         Rent  146.89       House rent payment  Mobile Payment
# 136  2025-06-28   Healthcare  315.14                 Eye exam  Mobile Payment
#
#      Cashback
# 0       18.77
# ...

# %%
import pandas as pd

# Path to your CSV file (provide the correct path where your CSV is stored)
csv_file = 'March_expenses.csv'  # Replace with your actual file path

# Read CSV into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the first few rows of the DataFrame to verify it
print(df)
# Out:
#            Date       Category  Amount         Description    Payment Mode  \
# 0    2025-03-23           Rent   98.04        Monthly rent            Cash
# 1    2025-03-07           Food  434.88      Fast food meal      Debit Card
# 2    2025-03-09    Investments  376.72        mutual funds     Credit Card
# 3    2025-03-18           Food  471.11    Weekly groceries  Mobile Payment
# 4    2025-03-22     Healthcare  192.88   Medicine purchase            Cash
# ..          ...            ...     ...                 ...             ...
# 140  2025-03-04           Rent  176.79  House rent payment      Debit Card
# 141  2025-03-21      Utilities  105.51    Electricity bill      Debit Card
# 142  2025-03-19  Entertainment  439.73      Concert ticket   Bank Transfer
# 143  2025-03-05     Stationary   76.88                Pens     Credit Card
# 144  2025-03-29    Investments  356.42                 LIC     Credit Card
#
#      Cashback
# 0        0.00
# 1       18.89
# 2       17.82
# ...

# %%
import pandas as pd

# Path to your CSV file (provide the correct path where your CSV is stored)
csv_file = 'April_expenses.csv'  # Replace with your actual file path

# Read CSV into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the first few rows of the DataFrame to verify it
print(df)
# Out:
#            Date       Category  Amount             Description  \
# 0    2025-04-24      Transport  439.49              Train fare
# 1    2025-04-18     Healthcare   91.00                Eye exam
# 2    2025-04-16     Stationary   93.85                  Charts
# 3    2025-04-14     Healthcare  334.03         Dental check-up
# 4    2025-04-20  Entertainment  486.99            Movie ticket
# ..          ...            ...     ...                     ...
# 120  2025-04-01      Transport  192.45               Taxi fare
# 121  2025-04-13  Entertainment  312.89  Streaming subscription
# 122  2025-04-03     Stationary  260.72         declutter boxes
# 123  2025-04-11      Transport   90.66              Car repair
# 124  2025-04-05       Shopping  441.74               New shoes
#
#        Payment Mode  Cashback
# 0        Debit Card     12.65
# 1    Mobile Payment      0.00
# 2    Mobile Payment      0.00
# 3       Credit Card     14.26
# 4     Bank Transfer      0.00
# ...

# %%
import pandas as pd

# Path to your CSV file (provide the correct path where your CSV is stored)
csv_file = 'May_expenses.csv'  # Replace with your actual file path

# Read CSV into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the first few rows of the DataFrame to verify it
print(df)
# Out:
#            Date       Category  Amount               Description  \
# 0    2025-05-15      Utilities   16.98     Internet subscription
# 1    2025-05-28           Rent  114.85         Room rent payment
# 2    2025-05-08      Utilities  275.39                Water bill
# 3    2025-05-25     Stationary  216.32                    Sheets
# 4    2025-05-17           Food    5.75            Coffee at café
# ..          ...            ...     ...                       ...
# 118  2025-05-13       Shopping  365.15  Shopping for accessories
# 119  2025-05-29  Entertainment   96.99               Video games
# 120  2025-05-07           Rent  363.71         Room rent payment
# 121  2025-05-27  Entertainment  335.64            Books purchase
# 122  2025-05-26      Transport  135.40                Car repair
#
#        Payment Mode  Cashback
# 0              Cash      0.00
# 1       Credit Card      6.08
# 2              Cash      0.00
# 3        Debit Card     14.19
# ...

# %%
import pandas as pd

# Path to your CSV file (provide the correct path where your CSV is stored)
csv_file = 'June_expenses.csv'  # Replace with your actual file path

# Read CSV into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the first few rows of the DataFrame to verify it
print(df)
# Out:
#            Date       Category  Amount        Description    Payment Mode  \
# 0    2025-06-03         Travel  216.88    Hastinapur tour   Bank Transfer
# 1    2025-06-11      Transport   14.31          Uber ride     Credit Card
# 2    2025-06-02      Utilities   39.60           Gas bill      Debit Card
# 3    2025-06-07  Entertainment  366.86       Movie ticket   Bank Transfer
# 4    2025-06-08         Travel   34.94         Mall visit     Credit Card
# ..          ...            ...     ...                ...             ...
# 132  2025-06-19       Shopping  496.81      Gift purchase     Credit Card
# 133  2025-06-04     Healthcare  111.02  Medicine purchase   Bank Transfer
# 134  2025-06-19       Shopping  306.59          New shoes      Debit Card
# 135  2025-06-24  Entertainment  219.51       Theatre show  Mobile Payment
# 136  2025-06-17      Utilities  168.53   Electricity bill   Bank Transfer
#
#      Cashback
# 0        0.00
# 1        0.73
# 2        1.30
# 3        0.00
# ...

# %%
import pandas as pd

# Path to your CSV file (provide the correct path where your CSV is stored)
csv_file = 'July_expenses.csv'  # Replace with your actual file path

# Read CSV into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the first few rows of the DataFrame to verify it
print(df)
# Out:
#            Date       Category  Amount             Description   Payment Mode  \
# 0    2025-07-02     Stationary  283.02                  Sheets    Credit Card
# 1    2025-07-27      Transport  448.12               Uber ride    Credit Card
# 2    2025-07-03    Investments   71.63            mutual funds           Cash
# 3    2025-07-02  Entertainment  109.79  Streaming subscription  Bank Transfer
# 4    2025-07-20  Entertainment  428.96  Streaming subscription  Bank Transfer
# ..          ...            ...     ...                     ...            ...
# 138  2025-07-17    Investments   76.81                  stocks           Cash
# 139  2025-07-27  Entertainment  338.19       Dinner and drinks           Cash
# 140  2025-07-11       Shopping   15.52           Gift purchase           Cash
# 141  2025-07-30    Investments  337.29                     LIC    Credit Card
# 142  2025-07-15     Stationary  161.36         declutter boxes    Credit Card
#
#      Cashback
# 0       12.69
# ...

# %%
import pandas as pd

# Path to your CSV file (provide the correct path where your CSV is stored)
csv_file = 'August_expenses.csv'  # Replace with your actual file path

# Read CSV into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the first few rows of the DataFrame to verify it
print(df)
# Out:
#            Date       Category  Amount              Description  \
# 0    2025-08-17       Shopping   50.67               Home decor
# 1    2025-08-11       Shopping  113.47            Gift purchase
# 2    2025-08-16      Utilities  185.79               Water bill
# 3    2025-08-28  Entertainment  258.73             Movie ticket
# 4    2025-08-13    Investments  117.10             mutual funds
# ..          ...            ...     ...                      ...
# 125  2025-08-10      Utilities   11.85        Mobile phone bill
# 126  2025-08-29  Entertainment  464.14   Streaming subscription
# 127  2025-08-04  Entertainment  155.33              Video games
# 128  2025-08-03      Utilities  360.76    Cable TV subscription
# 129  2025-08-20      Transport  269.15  Public transport ticket
#
#        Payment Mode  Cashback
# 0        Debit Card      2.52
# 1        Debit Card      3.38
# 2    Mobile Payment      0.00
# 3    Mobile Payment      0.00
# 4              Cash      0.00
# ...

# %%
import pandas as pd

# Path to your CSV file (provide the correct path where your CSV is stored)
csv_file = 'September_expenses.csv'  # Replace with your actual file path

# Read CSV into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the first few rows of the DataFrame to verify it
print(df)
# Out:
#            Date       Category  Amount              Description  \
# 0    2025-09-29     Healthcare  234.31           Gym membership
# 1    2025-09-04      Utilities  112.34        Mobile phone bill
# 2    2025-09-27     Stationary  145.05              Sketch Pens
# 3    2025-09-18      Utilities  188.87         Electricity bill
# 4    2025-09-30    Investments  277.86             mutual funds
# ..          ...            ...     ...                      ...
# 142  2025-09-28  Entertainment  476.69   Streaming subscription
# 143  2025-09-07      Transport   31.90  Public transport ticket
# 144  2025-09-11     Stationary   48.04                   Charts
# 145  2025-09-20         Travel  233.78               South Tour
# 146  2025-09-26           Rent  214.24             Monthly rent
#
#        Payment Mode  Cashback
# 0        Debit Card      9.27
# 1        Debit Card      2.20
# 2              Cash      0.00
# 3              Cash      0.00
# 4       Credit Card     20.25
# ...

# %%
import pandas as pd

# Path to your CSV file (provide the correct path where your CSV is stored)
csv_file = 'october_expenses.csv'  # Replace with your actual file path

# Read CSV into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the first few rows of the DataFrame to verify it
print(df)
# Out:
#            Date       Category  Amount             Description  \
# 0    2025-10-27      Utilities   12.42        Electricity bill
# 1    2025-10-08      Utilities  267.01        Electricity bill
# 2    2025-10-10       Shopping   68.23       Clothing purchase
# 3    2025-10-22         Travel  101.38                  Movies
# 4    2025-10-01  Entertainment  243.76          Concert ticket
# ..          ...            ...     ...                     ...
# 137  2025-10-02       Shopping  205.56      Bought electronics
# 138  2025-10-30           Food  461.11        Grocery shopping
# 139  2025-10-27           Rent  260.68          Apartment rent
# 140  2025-10-01  Entertainment  334.08  Streaming subscription
# 141  2025-10-27           Food  374.09        Grocery shopping
#
#        Payment Mode  Cashback
# 0     Bank Transfer      0.00
# 1       Credit Card      7.30
# 2        Debit Card      2.62
# 3              Cash      0.00
# 4     Bank Transfer      0.00
# ...

# %%
import pandas as pd

# Path to your CSV file (provide the correct path where your CSV is stored)
csv_file = 'November_expenses.csv'  # Replace with your actual file path

# Read CSV into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the first few rows of the DataFrame to verify it
print(df)
# Out:
#            Date       Category  Amount               Description Payment Mode  \
# 0    2025-10-29      Transport  160.98               Parking fee         Cash
# 1    2025-10-11         Travel  255.97                South Tour   Debit Card
# 2    2025-10-11     Healthcare  457.20                  Eye exam  Credit Card
# 3    2025-10-13           Food  156.94            Fast food meal   Debit Card
# 4    2025-10-07           Food  218.55       Lunch at restaurant         Cash
# ..          ...            ...     ...                       ...          ...
# 141  2025-10-06     Healthcare   14.56          Health insurance         Cash
# 142  2025-10-15     Healthcare  217.66           Dental check-up         Cash
# 143  2025-10-09       Shopping  488.92  Shopping for accessories         Cash
# 144  2025-10-27  Entertainment  393.57            Concert ticket  Credit Card
# 145  2025-10-18      Utilities  321.70         Mobile phone bill   Debit Card
#
#      Cashback
# 0        0.00
# ...

# %%
import pandas as pd

# Path to your CSV file (provide the correct path where your CSV is stored)
csv_file = 'December_expenses.csv'  # Replace with your actual file path

# Read CSV into a pandas DataFrame
df = pd.read_csv(csv_file)

# Display the first few rows of the DataFrame to verify it
print(df)
# Out:
#            Date       Category  Amount             Description  \
# 0    2025-10-14         Travel  239.49              South Tour
# 1    2025-10-13      Transport  102.57               Uber ride
# 2    2025-10-19     Stationary   21.98                  Charts
# 3    2025-10-13  Entertainment  374.81  Streaming subscription
# 4    2025-10-03      Utilities  353.72                Gas bill
# ..          ...            ...     ...                     ...
# 144  2025-10-10     Stationary  404.63                  Sheets
# 145  2025-10-28         Travel  173.66              Mall visit
# 146  2025-10-18     Stationary  267.93                    Pens
# 147  2025-10-29      Utilities  106.38   Cable TV subscription
# 148  2025-10-08      Utilities  107.45   Internet subscription
#
#        Payment Mode  Cashback
# 0     Bank Transfer      0.00
# 1    Mobile Payment      0.00
# 2       Credit Card      1.16
# 3     Bank Transfer      0.00
# 4     Bank Transfer      0.00
# ...

# %%
import pandas as pd
import os

# List of CSV file names
csv_files = ['january_expenses.csv', 'February_expenses.csv', 'March_expenses.csv','April_expenses.csv','May_expenses.csv','June_expenses.csv','July_expenses.csv','August_expenses.csv','September_expenses.csv','october_expenses.csv','November_expenses1.csv','December_expenses1.csv']

# Read and concatenate all CSV files
df_list = [pd.read_csv(file) for file in csv_files]
df_combined = pd.concat(df_list, axis=0, ignore_index=True)

# Display the combined DataFrame
print(df_combined)

# Optionally, save the concatenated DataFrame to a new CSV file
df_combined.to_csv('Annual_expense.csv', index=False)
# Out:
#             Date     Category  Amount              Description  \
# 0     2025-01-21    Transport  458.56  Public transport ticket
# 1     2025-01-17  Investments  295.81                   stocks
# 2     2025-01-17   Healthcare  422.57     Prescription glasses
# 3     2025-01-17     Shopping  378.60       Bought electronics
# 4     2025-01-01         Food   13.12      Lunch at restaurant
# ...          ...          ...     ...                      ...
# 1653  2025-12-09       Travel  335.53                   Movies
# 1654  2025-12-28  Investments  239.04                      LIC
# 1655  2025-12-22   Stationary  150.10          declutter boxes
# 1656  2025-12-28  Investments  285.12             mutual funds
# 1657  2025-12-23         Rent   36.82             Monthly rent
#
#         Payment Mode  Cashback
# 0         Debit Card     16.00
# 1      Bank Transfer      0.00
# 2               Cash      0.00
# 3        Credit Card     13.99
# 4               Cash      0.00
# ...

# %%
import pymysql
connection=pymysql.connect (
    host = "localhost",
    user = "root",
    port=3306,
    password="Password7"
)

# %%
# !pip install PyMySql

# %%
cursor=connection.cursor(

)

# %%
cursor.execute("use expense_db")
# Out:
# 0

# %%
import pandas as pd

# %%
df=pd.read_csv("Annual_expense.csv")
df.head()
# Out:
#          Date     Category  Amount              Description   Payment Mode  \
# 0  2025-01-21    Transport  458.56  Public transport ticket     Debit Card
# 1  2025-01-17  Investments  295.81                   stocks  Bank Transfer
# 2  2025-01-17   Healthcare  422.57     Prescription glasses           Cash
# 3  2025-01-17     Shopping  378.60       Bought electronics    Credit Card
# 4  2025-01-01         Food   13.12      Lunch at restaurant           Cash
#
#    Cashback
# 0     16.00
# 1      0.00
# 2      0.00
# 3     13.99
# 4      0.00

# %%
import pandas as pd
df3=pd.read_csv('Annual_expense.csv')
df3
# Out:
#             Date     Category  Amount              Description  \
# 0     2025-01-21    Transport  458.56  Public transport ticket
# 1     2025-01-17  Investments  295.81                   stocks
# 2     2025-01-17   Healthcare  422.57     Prescription glasses
# 3     2025-01-17     Shopping  378.60       Bought electronics
# 4     2025-01-01         Food   13.12      Lunch at restaurant
# ...          ...          ...     ...                      ...
# 1653  2025-12-09       Travel  335.53                   Movies
# 1654  2025-12-28  Investments  239.04                      LIC
# 1655  2025-12-22   Stationary  150.10          declutter boxes
# 1656  2025-12-28  Investments  285.12             mutual funds
# 1657  2025-12-23         Rent   36.82             Monthly rent
#
#         Payment Mode  Cashback
# 0         Debit Card     16.00
# 1      Bank Transfer      0.00
# 2               Cash      0.00
# 3        Credit Card     13.99
# 4               Cash      0.00
# ...

# %%
pip install sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine

# Load CSV into DataFrame
df1 = pd.read_csv("expenses_combined.csv")

# MySQL connection details
engine = create_engine("mysql+pymysql://root:Password7@localhost/expense_db")

# Upload DataFrame to MySQL
df1.to_sql("df1", con=engine, if_exists="replace", index=False)

print("DataFrame df1 successfully uploaded to MySQL!")
# Out:
# DataFrame df1 successfully uploaded to MySQL!

# %%
pip install streamlit pandas sqlalchemy pymysql matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import streamlit as st
import pandas as pd
from sqlalchemy import create_engine

#mysql connection
engine=create_engine("mysql+pymysql://root:Password7@localhost/expense_db")

#load data
query="SELECT * FROM expenses"
df=pd.read_sql(query, engine)

#streamlit UI
st.title("Expense Tracker - Monthly Analysis")

#show data
st.subheader("Expense Data")
st.write(df)

# Expense by Category (Bar Chart)
category_expense = pd.read_sql("SELECT category, SUM(amount) AS total FROM expenses GROUP BY category", engine)
st.subheader("🛒 Expenses by Category")
st.bar_chart(category_expense.set_index("category"))
# Out:
# 2025-01-29 15:48:25.835 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-29 15:48:25.989
# ...
#   command:
#
#     streamlit run C:\Users\Mansi\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-01-29 15:48:25.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-29 15:48:25.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-29 15:48:25.992 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-29 15:48:26.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-29 15:48:26.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Load CSV into DataFrame
df3 = pd.read_csv("Annual_expense.csv")

# MySQL connection details
engine = create_engine("mysql+pymysql://root:Password7@localhost/expense_db")

# Upload DataFrame to MySQL
df3.to_sql("df3", con=engine, if_exists="replace", index=False)

print("DataFrame df3 successfully uploaded to MySQL!")
# Out:
# DataFrame df3 successfully uploaded to MySQL!

# %%
pip install cryptography
# Out:
# ...
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.2 MB ? eta -:--:--
#    ------------- -------------------------- 1.0/3.2 MB 2.7 MB/s eta 0:00:01
#    ------------------- -------------------- 1.6/3.2 MB 2.7 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.2 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 2.9/3.2 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 2.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
